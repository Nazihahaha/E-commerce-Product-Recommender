# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/nazih/Desktop/E-commerce-Product-Recommender/marketing_sample_for_walmart_com-walmart_com_product_review__20200701_20201231__5k_data.tsv', sep='\t')

# %%
data.head(5)
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  1705736792d82aa2f2d3caf1c07c53f4  2020-09-24 03:21:12 +0000
# 1  95a9fe6f4810fcfc7ff244fd06784f11  2020-10-30 14:04:08 +0000
# 2  8d4d0330178d3ed181b15a4102b287f2  2020-08-06 05:51:47 +0000
# 3  fddc4df45b35efd886794b261f730c51  2020-07-15 11:22:04 +0000
# 4  0990cf89a59ca6a0460349a3e4f51d42  2020-11-26T12:27:20+00:00
#
#    Dataset Origin                        Product Id  Product Barcode  \
# 0             NaN  2e17bf4acecdece67fc00f07ad62c910              NaN
# 1             NaN  076e5854a62dd283c253d6bae415af1f              NaN
# 2             NaN  8a4fe5d9c7a6ed26cc44d785a454b124              NaN
# 3             NaN  03b5fb878a33eadff8b033419eab9669              NaN
# 4             NaN  ce3d761e57d6ccad80619297b5b1bcbc              NaN
#
#   Product Company Type Source Product Brand Source  \
# 0                  Competitor                  NaN
# 1                  Competitor                  NaN
# ...

# %%
data.isnull().sum()
# Out:
# Uniq Id                               0
# Crawl Timestamp                       0
# Dataset Origin                     5000
# Product Id                            0
# Product Barcode                    5000
# Product Company Type Source           0
# Product Brand Source               4861
# Product Brand Normalised Source    4861
# Product Name Source                4861
# Match Rank                         5000
# Match Score                        5000
# Match Type                         5000
# Retailer                              0
# Product Category                     10
# Product Brand                        13
# Product Name                          0
# Product Price                        42
# Sku                                5000
# Upc                                5000
# Product Url                           0
# Market                                0
# Product Description                1127
# Product Currency                      0
# ...

# %%
data.shape
# Out:
# (5000, 32)

# %%
df = data.copy()
df.drop(columns=['Dataset Origin', 'Product Barcode', 'Bsr', 'Upc', 'Sku'] , inplace=True)

# %%
df.shape
# Out:
# (5000, 27)

# %%
df.describe()
# Out:
#        Match Rank  Match Score  Match Type  Product Price  \
# count         0.0          0.0         0.0    4958.000000
# mean          NaN          NaN         NaN      23.364425
# std           NaN          NaN         NaN      35.182204
# min           NaN          NaN         NaN       0.100000
# 25%           NaN          NaN         NaN       8.400000
# 50%           NaN          NaN         NaN      14.950000
# 75%           NaN          NaN         NaN      26.007500
# max           NaN          NaN         NaN     722.450000
#
#        Product Available Inventory  Product Model Number  Product Contents  \
# count                       5000.0                   0.0               0.0
# mean                   111111111.0                   NaN               NaN
# std                            0.0                   NaN               NaN
# min                    111111111.0                   NaN               NaN
# ...

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Uniq Id                               0
# Crawl Timestamp                       0
# Product Id                            0
# Product Company Type Source           0
# Product Brand Source               4861
# Product Brand Normalised Source    4861
# Product Name Source                4861
# Match Rank                         5000
# Match Score                        5000
# Match Type                         5000
# Retailer                              0
# Product Category                     10
# Product Brand                        13
# Product Name                          0
# Product Price                        42
# Product Url                           0
# Market                                0
# Product Description                1127
# Product Currency                      0
# Product Available Inventory           0
# Product Image Url                     0
# Product Model Number               5000
# Product Tags                          0
# ...

# %%
# Drop rows where Product Description is missing
df = df.dropna(subset=['Product Description'])

# Impute missing numerical values with median (or 0 if preferred)
df['Product Rating'] = df['Product Rating'].fillna(df['Product Rating'].median())
df['Product Reviews Count'] = df['Product Reviews Count'].fillna(0)

# %%
# Verify no missing values remain in key columns
print(df[['Product Description', 'Product Rating', 'Product Reviews Count']].isnull().sum())
# Out:
# Product Description      0
# Product Rating           0
# Product Reviews Count    0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Uniq Id                               0
# Crawl Timestamp                       0
# Product Id                            0
# Product Company Type Source           0
# Product Brand Source               3737
# Product Brand Normalised Source    3737
# Product Name Source                3737
# Match Rank                         3873
# Match Score                        3873
# Match Type                         3873
# Retailer                              0
# Product Category                     10
# Product Brand                        13
# Product Name                          0
# Product Price                        39
# Product Url                           0
# Market                                0
# Product Description                   0
# Product Currency                      0
# Product Available Inventory           0
# Product Image Url                     0
# Product Model Number               3873
# Product Tags                          0
# ...
